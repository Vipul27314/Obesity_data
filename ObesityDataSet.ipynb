# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Admin\Downloads\ObesityDataSet_raw_and_data_sinthetic.csv', encoding = 'unicode_escape')

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.head()
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# 0                            yes  0.0  1.0  Sometimes  Public_Transportation
# 1                            yes  3.0  0.0  Sometimes  Public_Transportation
# 2                            yes  2.0  1.0  Sometimes  Public_Transportation
# 3                             no  2.0  0.0  Sometimes                Walking
# 4                             no  0.0  0.0  Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
df.head(10)
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
# 5  29.0    Male    1.62    53.0   Sometimes  yes   2.0  3.0   no    no   2.0
# 6  23.0  Female    1.50    55.0   Sometimes  yes   3.0  3.0   no    no   2.0
# 7  22.0    Male    1.64    53.0   Sometimes   no   2.0  3.0   no    no   2.0
# 8  24.0    Male    1.78    64.0  Frequently  yes   3.0  3.0   no    no   2.0
# 9  22.0    Male    1.72    68.0          no  yes   2.0  3.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
pd.isnull(df).sum()
# Out:
# Age                               0
# Gender                            0
# Height                            0
# Weight                            0
# CALC                              0
# FAVC                              0
# FCVC                              0
# NCP                               0
# SCC                               0
# SMOKE                             0
# CH2O                              0
# family_history_with_overweight    0
# FAF                               0
# TUE                               0
# CAEC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df['Age']= df['Age'].astype('int')

# %%
df['Age'].dtypes
# Out:
# dtype('int32')

# %%
df['FCVC'] = df['FCVC'].astype('int')

# %%
df['FCVC'].dtypes
# Out:
# dtype('int32')

# %%
df['NCP'] = df['NCP'].astype('int')

# %%
df['NCP'].dtypes
# Out:
# dtype('int32')

# %%
df['CH2O'] = df['CH2O'].astype('int')

# %%
df['CH2O'].dtypes
# Out:
# dtype('int32')

# %%
df['FAF'] = df['FAF'].astype('int')

# %%
df['FAF'] .dtypes
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   int32
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   int32
#  7   NCP                             2111 non-null   int32
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   int32
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df['TUE'] = df['TUE'].astype('int')

# %%
df['TUE'].dtypes
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   int32
#  1   Gender                          2111 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   int32
#  7   NCP                             2111 non-null   int32
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   int32
#  11  family_history_with_overweight  2111 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     23.972525     1.701677    86.586058     2.213169     2.523449
# std       6.308664     0.093305    26.191172     0.599397     0.830288
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.000000     1.630000    65.473343     2.000000     2.000000
# 50%      22.000000     1.700499    83.000000     2.000000     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      1.712459     0.734723     0.381336
# std       0.598760     0.832812     0.582536
# min       1.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000
# 50%       2.000000     1.000000     0.000000
# ...

# %%
df[['Age', 'CH2O' , 'FAF']] .describe()
# Out:
#                Age         CH2O          FAF
# count  2111.000000  2111.000000  2111.000000
# mean     23.972525     1.712459     0.734723
# std       6.308664     0.598760     0.832812
# min      14.000000     1.000000     0.000000
# 25%      19.000000     1.000000     0.000000
# 50%      22.000000     2.000000     1.000000
# 75%      26.000000     2.000000     1.000000
# max      61.000000     3.000000     3.000000

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Gender

# %%
sns.countplot( x = 'Age' , data = df)
sns.set(rc={'figure.figsize':(20,5)})

# %%
ax = sns.countplot( x = 'Age' , data = df)
sns.set(rc={'figure.figsize':(20,5)})

for i in ax.containers:
    ax.bar_label(i)

# %%
df.groupby(['Gender'],as_index=False)['Age'].sum().sort_values( by ='Age' , ascending=False)
# Out:
#    Gender    Age
# 1    Male  25940
# 0  Female  24666

# %%
ax = df.groupby(['Gender'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'Gender', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
ax = df.groupby(['CALC'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CALC', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='CALC', ylabel='Age'>

# %%
ax = df.groupby(['FAVC'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FAVC', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='FAVC', ylabel='Age'>

# %%
ax = df.groupby(['SCC'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'SCC', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='SCC', ylabel='Age'>

# %%
ax = df.groupby(['SMOKE'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'SMOKE', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='SMOKE', ylabel='Age'>

# %%
ax = df.groupby(['family_history_with_overweight'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'family_history_with_overweight', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='Age'>

# %%
ax = df.groupby(['CAEC'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CAEC', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='CAEC', ylabel='Age'>

# %%
ax = df.groupby(['MTRANS'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'MTRANS', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='MTRANS', ylabel='Age'>

# %%
ax = df.groupby(['NObeyesdad'],as_index = False)['Age'].sum().sort_values(by = 'Age' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'NObeyesdad', y = 'Age' , data = ax)
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='Age'>

# %%
ax = df.groupby(['Gender'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'Gender', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
ax = df.groupby(['CALC'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CALC', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='CALC', ylabel='Height'>

# %%
ax = df.groupby(['FAVC'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FAVC', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='FAVC', ylabel='Height'>

# %%
ax = df.groupby(['FCVC'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FCVC', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='FCVC', ylabel='Height'>

# %%
ax = df.groupby(['Age'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'Age', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
ax = df.groupby(['NCP'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'NCP', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='NCP', ylabel='Height'>

# %%
ax = df.groupby(['SCC'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'SCC', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='SCC', ylabel='Height'>

# %%
ax = df.groupby(['SMOKE'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'SMOKE', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='SMOKE', ylabel='Height'>

# %%
ax = df.groupby(['CH2O'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CH2O', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='CH2O', ylabel='Height'>

# %%
ax = df.groupby(['family_history_with_overweight'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'family_history_with_overweight', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='Height'>

# %%
ax = df.groupby(['FAF'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FAF', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='FAF', ylabel='Height'>

# %%
ax = df.groupby(['TUE'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'TUE', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='TUE', ylabel='Height'>

# %%
ax = df.groupby(['CAEC'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CAEC', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='CAEC', ylabel='Height'>

# %%
ax = df.groupby(['MTRANS'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'MTRANS', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='MTRANS', ylabel='Height'>

# %%
ax = df.groupby(['NObeyesdad'],as_index = False)['Height'].sum().sort_values(by = 'Height' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'NObeyesdad', y = 'Height' , data = ax)
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='Height'>

# %%
ax = df.groupby(['Age'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'Age', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
ax = df.groupby(['Gender'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'Gender', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='Gender', ylabel='Weight'>

# %%
ax = df.groupby(['CALC'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CALC', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='CALC', ylabel='Weight'>

# %%
ax = df.groupby(['FAVC'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FAVC', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='FAVC', ylabel='Weight'>

# %%
ax = df.groupby(['FCVC'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FCVC', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='FCVC', ylabel='Weight'>

# %%
ax = df.groupby(['NCP'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'NCP', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='NCP', ylabel='Weight'>

# %%
ax = df.groupby(['SCC'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'SCC', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='SCC', ylabel='Weight'>

# %%
ax = df.groupby(['SMOKE'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'SMOKE', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='SMOKE', ylabel='Weight'>

# %%
ax = df.groupby(['CH2O'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CH2O', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='CH2O', ylabel='Weight'>

# %%
ax = df.groupby(['family_history_with_overweight'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'family_history_with_overweight', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='Weight'>

# %%
ax = df.groupby(['FAF'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'FAF', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='FAF', ylabel='Weight'>

# %%
ax = df.groupby(['TUE'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'TUE', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='TUE', ylabel='Weight'>

# %%
ax = df.groupby(['CAEC'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'CAEC', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='CAEC', ylabel='Weight'>

# %%
ax = df.groupby(['MTRANS'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'MTRANS', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='MTRANS', ylabel='Weight'>

# %%
ax = df.groupby(['NObeyesdad'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'NObeyesdad', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='Weight'>

# %%
ax = df.groupby(['NObeyesdad'],as_index = False)['Weight'].sum().sort_values(by = 'Weight' , ascending=False)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot( x = 'NObeyesdad', y = 'Weight' , data = ax)
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='Weight'>
